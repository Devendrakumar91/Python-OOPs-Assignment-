# %% [markdown]
# **Python OOPs Assignment**

# %% [markdown]
# Q- 1 What is Object-Oriented Programming (OOP)?
#
# Ans:- Object oriented programming (oop) is a programming paradigm based on the concept of objects. It consists of a set of methods and attributes. Actions are carried out using a class's object. Objects have two qualities : they exhibit states and actions. Methods represent its behaviour, while attributes represents its state.

# %% [markdown]
# Q- 2 What is a class in OOP?
#
# Ans:- The class is a user - defined data structure that combines the methods and data members into a single entity. For thr production of objects, classes serve as blueprints or code templets.

# %% [markdown]
# Q- 3  What is an object in OOP?
#
# Ans:- An enstance of a class is an object. It consists of a sets of methods and attributes. Actions are carried out using a class's object. objects have two qualities: They exibit states and actions. The object is equipped with properties and methods.

# %% [markdown]
# Q- 4 What is the difference between abstraction and encapsulation?
#
# Ans:- In Python, Abstraction is a key idea in object - oriented programming (OOP) that allows you to describe complicated systems by hiding unneeded details and exposing just essential aspects. It aids in management of programme complexity by breaking it down into smaller, more managebale sections.
#
# wihle in encpsulation in Python is a technique for combining data and functions into a single object. A class, for instance, contains all the data (methods and variables). Encapsulation refers to the broad concealment of an object's internal representation from areas outside of its specification.

# %% [markdown]
# Q-5 What are dunder methods in Python?
#
# Ans:- Dunder methods, also called as magic methods or special methods, in Python are special reserved methods that are surrounded by double underscores(ie. __ method __). these methods allow you to define how instance of your classes behave when they are used with built-in Python functions or operations.

# %% [markdown]
# Q-6  Explain the concept of inheritance in OOP.
#
# Ans:- Inheritance plays a significant role in an object - oriented programming language. Inhaeritance in Python refers to the process of a child class receiving the parent class's properties.
#
# The reuse of code is inheritance's main goal. Instead of starting from scratch when devloping a new class, we can use the existing class of instead of re-creating it from scratch.

# %% [markdown]
# Q- 7 What is polymorphism in OOP?
#
# Ans:- In OOP, Polymorphism refers to an object's capacity to assume several forms. simoly said, polymorphism enables us to carry out a single activity in a variety of ways. In Python polymorphism is achived by Method overloading and method overriding.

# %% [markdown]
# Q- 8 How is encapsulation achieved in python?
#
# Ans:- A class's data members and methods can be made private or protected in order achieve encapsulation. Direct access modifiers like public, and Private don't exist in Python. though, single and double underscores can be used to accomplish this.

# %% [markdown]
# Q- 9 What is a constructor in Python?
#
# Ans:- A constructor is a particular method used in object-oriented programming to generate and initialise an object of class. In the class, this method is defined. when an object is created, the constructor is automatically run. Declairing and initialising a class's instance and data member variables is the main function of the constructor.
#
# The constructor of three types
#
#   1- Default constructor
#
#   2- Non-parameterized constructor
#
#   3- parameterized constructor

# %% [markdown]
# Q- 10 What are class and static methods in Python?
#
# Ans:- **Class Method**
# This method is used to access or alter the class stste. If we exclusively use class variables when implementing a method, we should declare that method as a class method.
#
# **Static method**
# It is a general utility method that handles a single task. since this method is static and doesn't have access to class attributes, we don't use instance or class variables within it.

# %% [markdown]
# Q-11 What is method overloading in Python?
#
# Ans:- Method overlolading is the pracytice of invoking the same method more than once with different parameters. Method overloading is not supported by Python. Even if you over load the method, Python only takes into account the most recent definition. If you overloap a method in Python, a TypeError will be raised.
#
# ex.
#
#     def mul(x, y):
#       z = x*y
#       print(z)
#     def mul (p, q, r):
#       s = p*q*r
#       print("output:" ,s)
#     #mul(5, 6) error
#     mul(5, 2, 3)

# %% [markdown]
# Q-12 What is method overriding in OOP?
#
# Ans:- In Python, Method overriding is the process of providing a different implementation for a method that is already defined in the superclass within a subclass. It enables the subclass to define its own verison of a method with the same name and parameters as the method in the superclass.When a method is overridden, the subclass implements the method in it's own way, which overrides the behaviour defined in the superclass. the subclass can then alter or expand the functionality of the inherited method.

# %% [markdown]
# Q-13 What is a property decorator in Python?
#
# Ans:- In Python, the property decorator is used to make a method behave like an attribute.
#
# It allows you to:
#
# Access methods as if they were simple attributes (no need to use parentheses () when calling). Control how attributes are read, set, or deleted in a class. Implement getter, setter, and deleter methods in a clean way.

# %% [markdown]
# Q- 14 Why is polymorphism important in OOP?
#
# Ans- In OOP, polymorphism allows the same method (or operation) to behave differently depending on the object that calls it.
#
# Why it is important:-
#
# 1. Code Reusability
#
#   .You can write general code that works with multiple types of objects.
#
# 2. Flexibility & Extensibilty
#
#   .You can add new calsses without changing existing code
#
# 3. Cleaner and more readable code
#
#   .Polymorphism reduces long 'if-else' or 'switch' statement that check object types
#
# 4. Encapsulation of Behaviour
#
#   .Each class defines its own behaviour for a method, keeping code modular.

# %% [markdown]
# Q- 15 What is an abstract class in Python?
#
# Ans:- In Python, An abstract class is a class that cannot be instantiated directly (you can’t create objects from it).
# It is meant to provide a blueprint for other classes.
#
# Abstract classes may contain:
#
# . Abstract methods → methods declared but not implemented (must be overridden in child classes).
#
# . Concrete methods → methods with normal implementation.

# %% [markdown]
# Q- 16 What are the advantages of OOP?
#
# Ans:- The advantages of OOP
#
# 1. Modularity (Code Organization)
#
# - OOP organizes code into classes and objects.
#
# - Each class handles its own data and behavior.
#
# 2. Reusability
#
# - Through inheritance, you can reuse existing code instead of rewriting it.
#
# Example: A transportation class can be reused for Car, Bike, Bus without duplicating common features.
#
# 3. Encapsulation (Data Security)
#
# - Objects hide internal details and only expose necessary methods.
#
# - Prevents unauthorized access and reduces chances of accidental errors.
#
# 4. Polymorphism (Flexibility)
#
# - The same method name can work differently for different objects.
#
# - Example: speak() method → Dog says "Woof", Cat says "Meow".
#
# 5. Abstraction (Simplicity)
#
# - Shows only essential details while hiding complexity.
#
# - Example: You drive a car using the steering and pedals, without worrying about the engine’s inner working.
#
# 6. Scalability & Maintainability
#
# - Large software systems can be broken down into smaller, manageable objects.
#
# - Easier to debug, test, and update specific parts without affecting the whole program.
#
# 7. Real-World Modeling
#
# - OOP models real-world entities naturally (Car, Employee, Student).
#
# - Makes it intuitive for developers to design software.
#
# 8. Collaboration in Teams
#
# - Multiple developers can work on different classes/modules independently.
#
# - Example: One developer works on Payment, another on Order, and another on Customer class.

# %% [markdown]
# Q- 17 What is the difference between a class variable and an instance variable?
#
# Ans:- **Class variable**
#
# A variable that is declared inside a class but outside of any instance methods or init() methods is refered to as a class variable
#
#   **Instance variable**
#
# Instance variables are properties that are joined to a class instance. In the constructor ( the class's init() method), we define instance variable.

# %% [markdown]
# Q- 18 What is multiple inheritance in Python?
#
# And:- one child class may inherit from several parant classes when there is multiple inheritance. in OOp, multiple inheritance means that a class can inherit from more than one parant class. the child class gets access to attributes and methods of all its parent classes.

# %% [markdown]
# Q- 19  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
# Ans:-  "__str__"(self):
#
# This method is called when the str() function is used on an instance of the class. It should return a string representation of the object.
#
# ex.
#
#     class Myclass:
#       def __init__(self, x):
#           self.x = x
#
#       def __str__(self):
#           return f'Myclass instance with x = (self.x)
#     obj = myclass(5)
#     print(str(obj))
#
# "__repr__"(self):
#
#   This method is called when the repr()function is used on a instance of the class. It should return an unambiguous string representation of the object, which can be used to recreate the object.
#
#   ex.
#
#
#     class Myclass:
#       def __init__(self, x):
#           self.x = x
#
#       def __repr__(self):
#           return f'Myclass instance with x = (self.x)
#     obj = myclass(5)
#     print(repr(obj))

# %% [markdown]
# Q- 20 What is the significance of the ‘super()’ function in Python?
#
# Ans:- The super() function in Python is used to call methods from a parent (superclass) in a child (subclass).
#
# **Why is super() important?**
#
# 1. Avoids hardcoding parent class names
#
# - Instead of ParentClass.method(self), we use super().method().
#
# - Makes code easier to maintain if the class hierarchy changes.
#
# 2. Supports Multiple Inheritance (MRO)
#
# - With multiple inheritance, super() follows Method Resolution Order (MRO), ensuring each class in the hierarchy is called in the correct order.
#
# 3. Keeps Code DRY (Don’t Repeat Yourself)
#
# - Reduces duplication when extending functionality from parent classes.

# %% [markdown]
# Q- 21 What is the significance of the __del__ method in Python?
#
# Ans:- In Python, __del__ is a destructor method. It is automatically called when an object is about to be destroyed (garbage collected). Think of it as the "clean-up" method of a class.
#
# ex:
#
#     class MyClass:
#     def __del__(self):
#         print("Destructor called, object deleted")

# %% [markdown]
# Q- 22 What is the difference between @staticmethod and @classmethod in Python?
#
# Ans:- @staticmethod vs @classmethod in Python Both are used inside a class but they behave differently.
#
# 1. @staticmethod
#
# - Does not take 'self' or 'cls' as the first parameter.
#
# - It behaves just like a normal fuction, but it belongs to the class's namespace.
#
# - Can be called using class name or object.
#
# - Used when the method logic does not depend on instance (self) or class(cls).
#
# 2. @classmethod
#
# - Take 'cls' (class itself) as the first parameter.
#
# - Can access and modify class variables.
#
# - Often used for factory methods (alternative constructors)
#
# - Can be called using class name or object.

# %% [markdown]
# Q- 23 How does polymorphism work in Python with inheritance?
#
# Ans:- Polymorphism means "many forms" - the same method name can work differently depending on the object (or class) that calls it.
#
# when combined with inheritance, polymorphism allows child classes to provide their own implementation of methods inherited from a parent class.

# %% [markdown]
# Q- 24 What is method chaining in Python OOP?
#
# Ans:- Method chaining is an object-oriented programming (OOP) technique where multiple methods are called sequentially in a single line, because each method returns the object itself(self).
#
# This allows us to write code in a fluent style insted of calling each method seperately.
#
# **Benefits of Method Chaining**
#
# 1. Fluent and Readable Code → One line instead of multiple statements.
#
# 2. Less Repetition → No need to write variable names repeatedly.
#
# 3. Encapsulation → Keeps operations tied to the object.

# %% [markdown]
# Q- 25 What is the purpose of the __call__ method in Python?
#
# Ans:- In Python, the __call__ method allows an object of a class to be called like a function. If a class defines __call__, then creating an instance of that class makes the instance itself callable (just like a function).
#
# ex.
#
#     class MyClass:
#     def __call__(self, *args, **kwargs):
#
#         print("Object called with:", args, kwargs)

# %% [markdown]
# **Practical Questions**

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    print("generic message")

class Dog(Animal):
  def speak(self):
    print("Bark!")

# Create an instance of the Dog class and call the speak method
dog_instance = Dog()
dog_instance.speak()
# Out:
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


shapes = [
    Circle(5),
    Rectangle(4, 6)
]

for shape in shapes:
    print(f"{shape.__class__.__name__} area: {shape.area():.2f}")
# Out:
# Circle area: 78.54
# Rectangle area: 24.00

# %%
#  3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
  def __init__(self, type):
    self.type = type

class Car(Vehicle):
  def __init__(self, type, color):
    super().__init__(type)
    self.color = color

class ElectricCar(Car):
  def __init__(self, type, color, battery_kwh):
    super().__init__(type, color)
    self.battery_kwh = battery_kwh

# Example usage:
electric_car = ElectricCar("Electric Car", "Blue", 75)
print(f"Type: {electric_car.type}, Color: {electric_car.color}, Battery: {electric_car.battery_kwh} kWh")
# Out:
# Type: Electric Car, Color: Blue, Battery: 75 kWh

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    print("Bird is flying")

class Sparrow(Bird):
  def fly(self):
    print("Sparrow is flying")

class Penguin(Bird):
  def fly(self):
    print("Penguin is not flying")

# Example usage:
birds = [Sparrow(), Penguin()]

for bird in birds:
  bird.fly()
# Out:
# Sparrow is flying
# Penguin is not flying

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
  def __init__(self, balance):
    self.__balance = balance

  def deposit(self, amount):
    if amount > 0:
      self.__balance += amount
      print(f"Deposited: {amount}. New balance: {self.__balance}")
    else:
      print("Deposit amount must be positive.")

  def withdraw(self, amount):
    if amount > 0 and amount <= self.__balance:
      self.__balance -= amount
      print(f"Withdrew: {amount}. New balance: {self.__balance}")
    elif amount > self.__balance:
      print("Insufficient funds.")
    else:
      print("Withdrawal amount must be positive.")

  def check_balance(self):
    print(f"Current balance: {self.__balance}")

# Example usage:
account = BankAccount(5000)
account.deposit(10000)
account.withdraw(2300)
account.check_balance()
account.withdraw(35000) # Insufficient funds example
# Out:
# Deposited: 10000. New balance: 15000
# Withdrew: 2300. New balance: 12700
# Current balance: 12700
# Insufficient funds.

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()

class Instrument:
  def play(self):
    print("Instrument is playing")
class Guitar(Instrument):
  def play(self):
    print("Guitar is playing")
class Piano(Instrument):
  def play(self):
    print("Piano is playing")

# Example usage:
instruments = [Guitar(), Piano()]

for instrument in instruments:
  instrument.play()
# Out:
# Guitar is playing
# Piano is playing

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b
  @staticmethod
  def subtract_numbers(a, b):
    return a - b

    print(MathOperations.add_numbers(6, 5))
  print(MathOperations.subtract_numbers(15, 4))
# Out:
# 11

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person:
  count = 0
  def __init__(self):
    Person.count += 1
  @classmethod
  def get_count(cls):
    return Person.count

# Example usage:
person1 = Person()
person2 = Person()
person3 = Person()
person4 = Person()
person5 = Person()
person6 = Person()
person7 = Person()
person8 = Person()
person9 = Person()
print(f"Total number of persons created: {Person.get_count()}")
# Out:
# Total number of persons created: 9

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

# Example usage:
fraction = Fraction(2, 9)
print(fraction)
# Out:
# 2/9

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

class Vector:
  def __init__(self, a, b):
    self.a = a
    self.b = b

  def __add__(self, other):
    return Vector(self.a + other.a, self.b + other.b)

  def __str__(self):
    return f"Vector({self.a}, {self.b})"
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2
print(v3)
# Out:
# Vector(6, 8)

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, My name is {self.name} and I am {self.age} years old.")


p1 = Person("Devendra", 34)
p1.greet()

p2 = Person("Amit", 30)
p2.greet()
# Out:
# Hello, My name is Devendra and I am 34 years old.
# Hello, My name is Amit and I am 30 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    if len(self.grades) == 0:
      return 0
    return sum(self.grades) / len(self.grades)

    s1 = Student("Amit", [85, 90, 95])
  s2 = Student("Sunita", [70, 80, 90, 100])

  print(f"{s1.name}'s average grade: {s1.average_grade()}")
  print(f"{s2.name}'s average grade: {s2.average_grade()}")
# Out:
# Alice's average grade: 90.0
# Sunita's average grade: 85.0

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
  def __init__(self, length, width):
    self.length = length
    self.width = width
  def set_dimensions(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

# Example usage:
rectangle = Rectangle(5, 10)
print(f"Area of the rectangle: {rectangle.area()}")
# Out:
# Area of the rectangle: 50

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary

class Employee:
  def __init__(self, name, hours_worked, hourly_rate):
    self.name = name
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, name, hours_worked, hourly_rate, bonus):
    super().__init__(name, hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    return super().calculate_salary() + self.bonus

# Example usage:
employee = Employee("Devendra", 100, 20,)
manager = Manager("Sunita", 400, 25, 500)

print(f"{employee.name}'s salary: Rs {employee.calculate_salary()}")
print(f"{manager.name}'s salary: Rs {manager.calculate_salary()}")
# Out:
# Devendra's salary: Rs 2000
# Sunita's salary: Rs 10500

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

# Example usage:
product1 = Product("Laptop", 15000, 2)
product2 = Product("Mouse", 50, 5)

print(f"{product1.name} total price: Rs {product1.total_price()}")
print(f"{product2.name} total price: Rs {product2.total_price()}")
# Out:
# Laptop total price: Rs 30000
# Mouse total price: Rs 250

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return "Moo"

class Sheep(Animal):
  def sound(self):
    return "Baa"

# Example usage:
cow = Cow()
sheep = Sheep()

print(f"Cow says: {cow.sound()}")
print(f"Sheep says: {sheep.sound()}")
# Out:
# Cow says: Moo
# Sheep says: Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# Example usage:
book1 = Book("Five point some one", "Chetan bhagat", 2004)
print(book1.get_book_info())
# Out:
# Title: Five point some one, Author: Chetan bhagat, Year Published: 2004

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

# Example usage:
house = House("123 MG road", 3500000)
mansion = Mansion("420 Kings road", 1500000, 20)

print(f"House address: {house.address}, price: Rs {house.price}")
print(f"Mansion address: {mansion.address}, price: Rs {mansion.price}, rooms: {mansion.number_of_rooms}")
# Out:
# House address: 123 MG road, price: Rs 3500000
# Mansion address: 420 Kings road, price: Rs 1500000, rooms: 20
